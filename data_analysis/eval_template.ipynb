# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport experiment_results 

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import glasbey



pd.set_option('display.max_columns', None)
sns.set_theme(rc={'figure.figsize':(12, 6)})
sns.set_context("paper")
sns.set_style("whitegrid")

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

palette = glasbey.create_block_palette(
    [4, 3, 3, 2, 2],
    colorblind_safe=True,
    cvd_severity=90
)
sns.set_palette(palette)

dep_focus = ["baseline_vanilla_full","monolith_feature_monolith_full","serverless_feature_serverless_full"]
ms_focus = ["baseline_vanilla_full","obs_feature_object-storage_full","norec_feature_norecommendations_full"]
lable_names = {
    "baseline_vanilla_full": "Microservice Baseline",
    'jvm_jvm-impoove_full': "Runtime Improvement",
    'monolith_feature_monolith_full': "Monolith Variant",
    'norec_feature_norecommendations_full' : "Service Reduction",
    'obs_feature_object-storage_full' : "Infrastructure Service Replacement",
    'serverless_feature_serverless_full' : "Serverless Variant",
}

# %%
exr = experiment_results.ExperimentResults("data/results-8f86bd8f-0305-4ece-824f-d97093343429", load_stats_history=True, sut="teastore") # type: ignore
RUN_VARS = experiment_results.ExperimentResults.RUN_VARS # type: ignore

assert("loadgenerator" not in (list(exr.pods['name'].unique())))
assert("unkown" not in (list(exr.pods['instance'].unique())))
# Out:
# WARNING:root:dropped 1 outliers (3%)
# WARNING:root:dropped 2 outliers (5%)
# WARNING:root:dropped 4 outliers (10%)
# WARNING:root:dropped 1 outliers (6%)
# WARNING:root:loaded 135 datapoints with 8 outliers

# %%
display("NODES") # capslock = markdown fuer arme
display(exr.nodes.head())

display("PODS")
display(exr.pods.head())

display("STATS")
display(exr.stats.head())
# Out:
# 'NODES'
#                       instance     observation_time     collection_time  \
# 0  elise.ise.tu-berlin.de:9100  2025-12-29 13:16:18 2025-12-29 13:16:19
# 1            10.133.7.101:9100  2025-12-29 13:16:18 2025-12-29 13:16:19
# 2            10.133.7.100:9100  2025-12-29 13:16:18 2025-12-29 13:16:19
# 3         130.149.158.150:9100  2025-12-29 13:16:18 2025-12-29 13:16:19
# 4          130.149.158.32:9100  2025-12-29 13:16:18 2025-12-29 13:16:19
#
#    cpu_usage  memory_usage  network_usage  wattage  num_processes  \
# 0   0.478390      0.000000       0.007885        0              0
# 1   0.193600      0.201967       1.402645        0              0
# 2   1.942961      0.146776      16.961629        0              0
# 3   0.728200      0.266580       0.209248        0              0
# 4   0.515400      0.255533       0.512009        0              0
#
#    wattage_kepler  wattage_scaph  wattage_auxilary  temperture exp_workload  \
# 0          0.0000              0                 0         0.0       shaped
# 1          0.0000              0                 0         0.0       shaped
# 2          0.0000              0                 0         0.0       shaped
# 3         23.8257              0                 0        47.0       shaped
# 4         54.3955              0                 0        29.8       shaped
#
#   exp_branch                                     exp_start         run_start  \
# 0   baseline  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
# 1   baseline  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
# 2   baseline  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
# 3   baseline  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
# 4   baseline  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
#
#   run_iteration                run  \
# 0             0  baseline_shaped_0
# 1             0  baseline_shaped_0
# 2             0  baseline_shaped_0
# 3             0  baseline_shaped_0
# 4             0  baseline_shaped_0
#
#                                                 urun  wattage_kepler_zscore  \
# 0  results-8f86bd8f-0305-4ece-824f-d97093343429_b...              -0.528105
# 1  results-8f86bd8f-0305-4ece-824f-d97093343429_b...              -0.528105
# 2  results-8f86bd8f-0305-4ece-824f-d97093343429_b...              -0.528105
# 3  results-8f86bd8f-0305-4ece-824f-d97093343429_b...               1.548913
# 4  results-8f86bd8f-0305-4ece-824f-d97093343429_b...               4.213853
#
#    wattage_scaph_zscore  cpu_usage_zscore  memory_usage_zscore  \
# 0                   NaN         -0.326624            -1.598693
# 1                   NaN         -0.842740             0.567861
# 2                   NaN          2.327570            -0.024184
# 3                   NaN          0.126098             1.260985
# 4                   NaN         -0.259552             1.142483
#
#    network_usage_zscore run_time
# 0             -0.546222   0 days
# 1             -0.289762   0 days
# 2              2.571128   0 days
# 3             -0.509196   0 days
# 4             -0.453527   0 days
# 'PODS'
#       collection_time     observation_time                    name namespace  \
# 0 2025-12-29 13:16:20  2025-12-29 13:16:19  teastore-persistence-0  teastore
# 1 2025-12-29 13:16:20  2025-12-29 13:16:19           teastore-db-0  teastore
# 2 2025-12-29 13:16:20  2025-12-29 13:16:19     teastore-registry-0  teastore
# 3 2025-12-29 13:16:20  2025-12-29 13:16:19        teastore-image-0  teastore
# 4 2025-12-29 13:16:20  2025-12-29 13:16:19  teastore-recommender-0  teastore
#
#    cpu_usage  memory_usage  network_usage instance  wattage_kepler  \
# 0   0.049404    335.216640       0.000252   sm-gpu          0.3108
# 1   0.001350     34.965504       0.000005   sm-gpu          0.0060
# 2   0.049239     85.342208       0.003255   sm-gpu          0.1263
# 3   0.080583    406.410581       0.000434   sm-gpu          1.2057
# 4   0.083917    352.348843       0.000825   sm-gpu          0.4392
#
#    wattage_scaph exp_workload exp_branch  \
# 0       0.053319       shaped   baseline
# 1       0.001720       shaped   baseline
# 2       0.022360       shaped   baseline
# 3       0.223597       shaped   baseline
# 4       0.079119       shaped   baseline
#
#                                       exp_start         run_start  \
# 0  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
# 1  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
# 2  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
# 3  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
# 4  results-8f86bd8f-0305-4ece-824f-d97093343429  29_12_2025_13_16
#
#   run_iteration                run  \
# 0             0  baseline_shaped_0
# 1             0  baseline_shaped_0
# 2             0  baseline_shaped_0
# 3             0  baseline_shaped_0
# 4             0  baseline_shaped_0
#
#                                                 urun  wattage_kepler_zscore  \
# 0  results-8f86bd8f-0305-4ece-824f-d97093343429_b...              -0.435845
# 1  results-8f86bd8f-0305-4ece-824f-d97093343429_b...              -0.667400
# 2  results-8f86bd8f-0305-4ece-824f-d97093343429_b...              -0.576008
# 3  results-8f86bd8f-0305-4ece-824f-d97093343429_b...               0.244006
# 4  results-8f86bd8f-0305-4ece-824f-d97093343429_b...              -0.338300
#
#    wattage_scaph_zscore  cpu_usage_zscore  memory_usage_zscore  \
# 0             -0.387445         -0.551487             0.648061
# 1             -0.567056         -0.846941            -1.288436
# 2             -0.495212         -0.552501            -0.963527
# 3              0.205271         -0.359790             1.107233
# 4             -0.297640         -0.339290             0.758557
#
#    network_usage_zscore run_time              name_prefix  \
# 0             -0.530484   0 days  [teastore, persistence]
# 1             -0.534150   0 days           [teastore, db]
# 2             -0.485952   0 days     [teastore, registry]
# 3             -0.527799   0 days        [teastore, image]
# 4             -0.521996   0 days  [teastore, recommender]
#
#                pod_name
# 0  teastore-persistence
# 1           teastore-db
# 2     teastore-registry
# 3        teastore-image
# 4  teastore-recommender
# 'STATS'
#   Type       Name  Request Count  Failure Count  Median Response Time  \
# 0  GET  /category             62              1                    37
# 1  GET   /product             11              0                    67
# 0  GET  /category             66             66                     6
# 1  GET   /product             12             12                     6
#
#    Average Response Time  Min Response Time  Max Response Time  \
# 0             253.971434          24.139865        5584.551681
# 1             234.486914          45.457177        1182.797250
# 0               6.273658           4.571528          20.960796
# 1               6.181593           5.069925           8.197901
#
#    Average Content Size  Requests/s  Failures/s  50%  66%  75%  80%  90%  \
# 0         118651.596774    1.015340    0.016376   39   97  120  150  240
# 1         131982.636364    0.180141    0.000000   67   80  110  110  800
# 0              0.000000    1.092833    1.092833    6    6    7    7    8
# 1              0.000000    0.198697    0.198697    6    6    7    7    8
#
#     95%   98%   99%  99.9%  99.99%  100% exp_workload exp_branch  \
# 0   270  5100  5600   5600    5600  5600       shaped   baseline
# 1  1200  1200  1200   1200    1200  1200       shaped   baseline
# 0     8    12    21     21      21    21       shaped   monolith
# 1     8     8     8      8       8     8       shaped   monolith
#
#                                       exp_start run_start run_iteration  \
# 0  results-8f86bd8f-0305-4ece-824f-d97093343429                       0
# 1  results-8f86bd8f-0305-4ece-824f-d97093343429                       0
# 0  results-8f86bd8f-0305-4ece-824f-d97093343429                       0
# 1  results-8f86bd8f-0305-4ece-824f-d97093343429                       0
#
#                  run                                               urun
# 0  baseline_shaped_0  results-8f86bd8f-0305-4ece-824f-d97093343429_b...
# 1  baseline_shaped_0  results-8f86bd8f-0305-4ece-824f-d97093343429_b...
# 0  monolith_shaped_0  results-8f86bd8f-0305-4ece-824f-d97093343429_m...
# 1  monolith_shaped_0  results-8f86bd8f-0305-4ece-824f-d97093343429_m...
