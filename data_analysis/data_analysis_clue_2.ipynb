# %%
# %load_ext autoreload
# %autoreload 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from datetime import datetime

df_node = pd.read_csv("data/results-57a9d90a-068b-4fde-adcc-247d02918f5c/shaped/baseline/0/measurements_node_21_01_2026_06_48.csv")
df_pod = pd.read_csv("data/results-57a9d90a-068b-4fde-adcc-247d02918f5c/shaped/baseline/0/measurements_pod_21_01_2026_06_48.csv")
import pandas as pd

# Convert string to datetime objects
#df_pod["observation_time"] = pd.to_datetime(df_pod["observation_time"], format="%Y-%m-%d %H:%M:%S")
#df_pod = df_pod[df_pod["instance"] == "sm-gpu"]

fig, ax = plt.subplots(figsize=(12, 6))

# Loop through each unique name (e.g., pod name or version)
for name, group in df_pod.groupby("name"):
    ax.scatter(group["observation_time"], group["wattage_kepler"], label=name, alpha=0.6, s=15)

ax.legend(title="Resource Name", bbox_to_anchor=(0.75, 1), loc='upper left')
ax.set_xlabel("Time")
ax.set_ylabel("Joules")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
df_pod
# Out:
#         collection_time     observation_time                    name  \
# 0   2026-01-21 06:48:31  2026-01-21 06:48:31           teastore-db-0
# 1   2026-01-21 06:48:31  2026-01-21 06:48:31  teastore-persistence-0
# 2   2026-01-21 06:48:31  2026-01-21 06:48:31  teastore-recommender-0
# 3   2026-01-21 06:48:31  2026-01-21 06:48:31        teastore-webui-0
# 4   2026-01-21 06:48:31  2026-01-21 06:48:31        teastore-image-0
# 5   2026-01-21 06:48:31  2026-01-21 06:48:31         teastore-auth-0
# 6   2026-01-21 06:48:31  2026-01-21 06:48:31     teastore-registry-0
# 7   2026-01-21 06:48:31  2026-01-21 06:48:31           loadgenerator
# 8   2026-01-21 06:48:45  2026-01-21 06:48:44           teastore-db-0
# 9   2026-01-21 06:48:45  2026-01-21 06:48:44  teastore-persistence-0
# 10  2026-01-21 06:48:45  2026-01-21 06:48:44  teastore-recommender-0
# 11  2026-01-21 06:48:45  2026-01-21 06:48:44        teastore-webui-0
# 12  2026-01-21 06:48:45  2026-01-21 06:48:44        teastore-image-0
# 13  2026-01-21 06:48:45  2026-01-21 06:48:44         teastore-auth-0
# 14  2026-01-21 06:48:45  2026-01-21 06:48:44     teastore-registry-0
# 15  2026-01-21 06:48:45  2026-01-21 06:48:44           loadgenerator
# 16  2026-01-21 06:49:00  2026-01-21 06:48:59           teastore-db-0
# 17  2026-01-21 06:49:00  2026-01-21 06:48:59  teastore-persistence-0
# 18  2026-01-21 06:49:00  2026-01-21 06:48:59  teastore-recommender-0
# 19  2026-01-21 06:49:00  2026-01-21 06:48:59        teastore-webui-0
# 20  2026-01-21 06:49:00  2026-01-21 06:48:59        teastore-image-0
# 21  2026-01-21 06:49:00  2026-01-21 06:48:59         teastore-auth-0
# 22  2026-01-21 06:49:00  2026-01-21 06:48:59     teastore-registry-0
# 23  2026-01-21 06:49:00  2026-01-21 06:48:59           loadgenerator
# 24  2026-01-21 06:49:13  2026-01-21 06:49:13           teastore-db-0
# 25  2026-01-21 06:49:13  2026-01-21 06:49:13  teastore-persistence-0
# 26  2026-01-21 06:49:13  2026-01-21 06:49:13  teastore-recommender-0
# 27  2026-01-21 06:49:13  2026-01-21 06:49:13        teastore-webui-0
# 28  2026-01-21 06:49:13  2026-01-21 06:49:13        teastore-image-0
# 29  2026-01-21 06:49:13  2026-01-21 06:49:13         teastore-auth-0
# 30  2026-01-21 06:49:13  2026-01-21 06:49:13     teastore-registry-0
# 31  2026-01-21 06:49:13  2026-01-21 06:49:13           loadgenerator
#
#    namespace  cpu_usage  memory_usage  network_usage    instance  \
# 0   teastore   0.001252     78.165333       0.000395      sm-gpu
# 1   teastore   0.010290    547.392171       0.000165      gisele
# 2   teastore   0.014669    706.454869       0.000848      sm-gpu
# 3   teastore   0.022154   1026.656939       0.001020      sm-gpu
# 4   teastore   0.013251    762.997419       0.006086      sm-gpu
# 5   teastore   0.053864    863.786325       0.000444      gisele
# 6   teastore   0.005684    341.887659       0.002747      sm-gpu
# 7   teastore   0.000000      4.001792       0.000000  ise-knode3
# 8   teastore   0.001358     78.165333       0.001199      sm-gpu
# 9   teastore   0.032464    547.420843       0.001882      gisele
# 10  teastore   0.018883    706.497195       0.000919      sm-gpu
# 11  teastore   0.301636   1039.129259       0.036956      sm-gpu
# 12  teastore   0.035712    763.468459       0.039610      sm-gpu
# 13  teastore   0.056345    863.809536       0.000845      gisele
# 14  teastore   0.005921    341.887659       0.003333      sm-gpu
# 15  teastore   0.057334     22.799701       0.043893  ise-knode3
# 16  teastore   0.001857     78.165333       0.002743      sm-gpu
# 17  teastore   0.044006    547.489109       0.009150      gisele
# 18  teastore   0.019940    706.505387       0.000968      sm-gpu
# 19  teastore   0.081249   1037.161813       0.193503      sm-gpu
# 20  teastore   0.058121    764.746411       0.090205      sm-gpu
# 21  teastore   0.017909    863.825920       0.001310      gisele
# 22  teastore   0.006370    341.887659       0.003287      sm-gpu
# 23  teastore   0.019443     23.224320       0.099746  ise-knode3
# 24  teastore   0.001841     78.165333       0.003996      sm-gpu
# 25  teastore   0.055386    547.654315       0.010733      gisele
# 26  teastore   0.046155    706.513579       0.001008      sm-gpu
# 27  teastore   0.091027   1037.778944       0.246926      sm-gpu
# 28  teastore   0.047918    766.145877       0.132687      sm-gpu
# 29  teastore   0.036858    863.992491       0.001886      gisele
# 30  teastore   0.005899    341.889024       0.003271      sm-gpu
# 31  teastore   0.018835     23.539712       0.102401  ise-knode3
#
#     wattage_kepler  wattage_kepler_new  wattage_scaph
# 0           0.0048            0.000000            0.0
# 1           0.2100            0.015316            0.0
# 2           0.1134            0.018014            0.0
# 3           2.8782            0.507986            0.0
# 4           0.2154            0.021616            0.0
# 5           0.3912            0.022975            0.0
# 6           0.0318            0.007205            0.0
# 7           0.0000            0.000000            0.0
# 8           0.0024            0.000000            0.0
# 9           0.1458            0.197440            0.0
# 10          0.0540            0.020626            0.0
# 11          0.0714            0.096253            0.0
# 12          0.0588            0.103129            0.0
# 13          0.1158            0.041133            0.0
# 14          0.0174            0.006875            0.0
# 15          0.0000            0.000000            0.0
# 16          0.0048            0.003854            0.0
# 17          0.1398            0.139903            0.0
# 18          0.5262            0.015416            0.0
# 19          0.3168            0.134893            0.0
# 20          0.0846            0.038541            0.0
# 21          0.0792            0.041971            0.0
# 22          0.0258            0.003854            0.0
# 23          0.0000            0.000000            0.0
# 24          0.0048            0.000000            0.0
# 25          0.3342            0.072960            0.0
# 26          0.0756            0.015751            0.0
# 27          0.3330            0.078753            0.0
# 28          0.1482            0.035439            0.0
# 29          0.1320            0.043776            0.0
# 30          0.0156            0.003938            0.0
# 31          0.0000            0.000000            0.0

# %%
from experiment_loader import ExperimentLoader
loader = ExperimentLoader()
experiments = loader.get_experiment_names()

shaped = loader.get_iteration(experiments[-1], workload="shaped")
# pausing = loader.get_iteration(experiments[-1], workload="pausing-long")
# rampup = loader.get_iteration(experiments[-1], workload="rampup-long")
# fixed = loader.get_iteration(experiments[-1], workload="fixed-long")

df_pods_shaped = loader.load_pod_measurements(shaped, drop_outliers = True)
# df_pods_pausing = loader.load_pod_measurements(pausing, drop_outliers = True)
# df_pod_rampup = loader.load_pod_measurements(rampup, drop_outliers = True)
# df_pod_fixed = loader.load_pod_measurements(fixed, drop_outliers = True)
df_pods_shaped["observation_time"].unique()
loader.get_experiment_length(df_pods_shaped)/60
# Out:
# dropped 166 outliers (8%)
# np.float64(39.31666666666667)

# %%
loader.get_experiment_names()
# Out:
# ['results-57a9d90a-068b-4fde-adcc-247d02918f5c',
#  'results-171bd8e0-0e9f-44ef-a398-fabf5a70c705',
#  'results-a6aee91c-ff84-4249-9bb4-cb25ed2619e5',
#  'results-22eb1ae3-0de3-4ce3-9d4f-93f01058c5d5',
#  'results-513de4f1-1980-4bed-a578-d02311fb9127',
#  'results-6d4f426e-b02a-4ff8-9247-eac88e932acc',
#  'long_run_gisele']

# %%
#Trying out shelly
from experiment_loader import ExperimentLoader
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MaxNLocator

loader = ExperimentLoader()
experiments = loader.get_experiment_names()
shaped_shelly = loader.get_iteration(experiments[-1], workload="shaped")
df = loader.load_node_measurements(shaped_shelly)

# Filtering for the specific instance
gisele_df = df[df["instance"] == "sm-gpu"]

fig, ax = plt.subplots(figsize=(10, 6))

# Define metrics and get viridis colors
metrics = ["wattage", "wattage_scaph", "wattage_kepler", "wattage_kepler_new"]
labels = ["Shelly Wattage", "Wattage Scaph", "Wattage Kepler", "Wattage Kepler New"]
colors = plt.cm.viridis(np.linspace(0, 1, len(metrics)))

# Plotting each metric with a viridis color
for i, metric in enumerate(metrics):
    ax.plot(gisele_df["relative_seconds"], gisele_df[metric], 
            label=labels[i], color=colors[i], linewidth=2, alpha=0.8)

# Formatting
ax.set_xlabel("Time (s)")
ax.xaxis.set_major_locator(MaxNLocator(nbins=10))
ax.set_ylabel("Power (Watts)")
ax.set_xlim(600, 2400)
ax.legend()
plt.xticks(rotation=45, )
#plt.grid(True, linestyle='--', alpha=0.6)
# Save as .eps for that high-quality vector format we discussed!
fig.savefig('figs/node_wattage.eps', format='eps', bbox_inches='tight')

plt.show()

plt.tight_layout()
plt.show()


df
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#     instance     observation_time      collection_time  cpu_usage  \
# 0     sm-gpu  2026-02-03 20:45:34  2026-02-03 20:45:37     3.7372
# 1     sm-gpu  2026-02-03 20:45:49  2026-02-03 20:45:51     4.4260
# 2     sm-gpu  2026-02-03 20:46:04  2026-02-03 20:46:07     4.3262
# 3     sm-gpu  2026-02-03 20:46:19  2026-02-03 20:46:20     4.2610
# 4     sm-gpu  2026-02-03 20:46:32  2026-02-03 20:46:34     3.9582
# ..       ...                  ...                  ...        ...
# 162   sm-gpu  2026-02-03 21:23:56  2026-02-03 21:23:57     1.8236
# 163   sm-gpu  2026-02-03 21:24:10  2026-02-03 21:24:11     1.8468
# 164   sm-gpu  2026-02-03 21:24:24  2026-02-03 21:24:26     1.0942
# 165   sm-gpu  2026-02-03 21:24:39  2026-02-03 21:24:41     0.7884
# 166   sm-gpu  2026-02-03 21:24:54  2026-02-03 21:24:56     0.9804
#
#      memory_usage  network_usage  wattage  num_processes  wattage_kepler  \
# 0        0.367586       1.883249        0             52         32.9634
# 1        0.380941       1.897193        0             55         40.3102
# 2        0.415577       1.568510        0             55         29.7786
# 3        0.423980       1.453034        0             56         39.0871
# 4        0.460538       1.513383        0             56         29.7181
# ..            ...            ...      ...            ...             ...
# 162      0.471459       1.482038        0             54         19.3369
# 163      0.465891       1.498259        0             54         17.5376
# 164      0.426860       1.472708        0             54         18.8385
# 165      0.401371       1.489042        0             54         13.4407
# 166      0.377134       1.467316        0             54         23.4280
#
#      wattage_kepler_new  wattage_scaph  wattage_auxilary  temperture  \
# 0             33.940419      34.174568          3.886225          50
# 1             33.261984      33.169767          8.471799          51
# 2             33.839093      33.571768          8.875847          51
# 3             32.917293      32.871723          9.718283          51
# 4             33.274860      33.243409          9.337091          51
# ..                  ...            ...               ...         ...
# 162           20.797483      20.814611          2.134563          51
# 163           17.523938      17.399267          0.395637          51
# 164           14.812853      14.809336          0.417217          51
# 165           16.204605      16.496558          0.497926          51
# 166           26.446148      26.460702          4.120217          51
#
#      relative_seconds
# 0                   0
# 1                  15
# 2                  30
# 3                  45
# 4                  58
# ..                ...
# 162              2302
# 163              2316
# 164              2330
# 165              2345
# 166              2360
#
# [167 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Access the Viridis colormap
# We'll take two colors: one at 20% and one at 80% of the scale
cmap = plt.get_cmap('viridis')
color_v09 = cmap(0.2)   # Deep Purple/Blue
color_v11 = cmap(0.8)   # Bright Yellow/Green

data_to_plot = [
    df_pods_shaped["wattage_kepler"], df_pods_shaped["wattage_kepler_new"]
    # df_pods_pausing["wattage_kepler"], df_pods_pausing["wattage_kepler_new"],
    # df_pod_rampup["wattage_kepler"], df_pod_rampup["wattage_kepler_new"],
    # df_pod_fixed["wattage_kepler"], df_pod_fixed["wattage_kepler_new"]
]

positions = [1, 2]# , 4, 5, 7, 8, 10, 11]
fig, ax = plt.subplots(figsize=(12, 6))

# 2. Create the boxplot
bp = ax.boxplot(data_to_plot, positions=positions, widths=0.6, patch_artist=True,
                medianprops={"color": "black"})

# 3. Apply Viridis colors alternately
colors = [color_v09, color_v11] * 4
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.8) # Slight transparency looks cleaner

# 4. Styling
ax.set_ylabel('Wattage')
ax.set_xticks([1.5, 4.5, 7.5, 10.5])
ax.set_xticklabels(['Shaped', 'Pausing', 'Rampup', 'Fixed'])

# 5. Legend
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor=color_v09, label='Kepler 0.9.0'),
    Patch(facecolor=color_v11, label='Kepler 0.11.2')
]
ax.legend(handles=legend_elements, loc='upper right')

plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()

# Save as .eps for that high-quality vector format we discussed!
fig.savefig('figs/kepler_comparison_viridis.eps', format='eps', bbox_inches='tight')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Choose a workload to visualize (e.g., 'rampup')
# We need to add a 'Version' column so Seaborn can distinguish them
df_pods_shaped["Version"] = "Kepler 0.9.0"
df_pods_shaped["Version"] = "Kepler 0.11.2"

# 2. Combine the dataframes
# Assuming you have a 'timestamp' or 'time' column
combined_df = pd.concat([df_pods_shaped, df_pods_shaped])

# 3. Plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=combined_df, x="observation_time", y="wattage_kepler", 
             hue="Version", palette="viridis")

# Styling
plt.title("Wattage Trend Over Time: Rampup Workload")
plt.ylabel("Wattage")
plt.xlabel("Time (s)")
plt.grid(True, alpha=0.3)

# Save as PDF for LaTeX (Vector format)
plt.savefig("wattage_timeseries.pdf", bbox_inches='tight')
plt.show()
